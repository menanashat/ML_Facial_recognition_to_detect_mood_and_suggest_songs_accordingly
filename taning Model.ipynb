# %%
#import libraries
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.constraints import maxnorm
from keras.optimizers import SGD ,Adam
from keras.layers.convolutional import Conv2D
from keras.layers import Dense, Conv2D ,Flatten,Dropout,MaxPool2D, BatchNormalization
from keras.utils import np_utils
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory  
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import Xception
import keras
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np 
import tensorflow as tf
import pandas as pd
import seaborn
from sklearn.metrics import confusion_matrix , classification_report

# %%
#import our data
train_datagen = ImageDataGenerator(
    rescale=1. / 255,rotation_range=10, fill_mode='nearest',
     featurewise_center=True,
    featurewise_std_normalization=True,
    vertical_flip= True,
    shear_range=0.2,
    zoom_range=0.2,
    brightness_range = (0.4,0.6),
    horizontal_flip=True,validation_split=0.2)
test_datagen = ImageDataGenerator(
    rescale=1. / 255)

# %%
train_generator = train_datagen.flow_from_directory(
    'C://Users//mm//Desktop//train',
    target_size=(48, 48),
    batch_size=64, color_mode = "grayscale" , class_mode  = "binary"
  )
# Out:
# Found 28709 images belonging to 7 classes.

# %%
test_generator  = test_datagen.flow_from_directory(
    'C://Users//mm//Desktop//test',
    target_size=(48, 48),
    batch_size=64 , color_mode = "grayscale" , class_mode  = "binary"
  )
# Out:
# Found 7178 images belonging to 7 classes.

# %%
test_dataset = image_dataset_from_directory('C://Users//mm//Desktop//test',
                                             shuffle=True,
                                             batch_size=32,color_mode = "grayscale",image_size=(48,48))
class_name =  test_dataset.class_names
plt.figure(figsize = (10,10))
for image,label  in test_dataset:
    for i in range(9) :
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype("uint8"))
        plt.title(class_name[label[i]])
        plt.axis("off")
# Out:
# Found 7178 files belonging to 7 classes.

# %%
#create our model
from keras import regularizers

model =  tf.keras.models.Sequential() 
model.add(Conv2D(32,(3,3), activation='relu' ,input_shape = (48,48,1)))
model.add(Conv2D(64,(3,3),  activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D())
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3), activation='relu' , kernel_regularizer=regularizers.l2(0.01)))
model.add(Conv2D(256,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPool2D())
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 44, 44, 64)        18496
#
#  batch_normalization (BatchN  (None, 44, 44, 64)       256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 22, 22, 64)       0
#  )
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 20, 20, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 256)       295168
#
#  batch_normalization_1 (Batc  (None, 18, 18, 256)      1024
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 9, 9, 256)         0
#
#  flatten (Flatten)           (None, 20736)             0
#
#  dense (Dense)               (None, 1024)              21234688
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 21,630,983
# Trainable params: 21,630,343
# Non-trainable params: 640
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(lr=0.0001), 
                  loss='sparse_categorical_crossentropy', 
                  metrics=['accuracy'])
# Out:
# C:\Users\mm\AppData\Roaming\Python\Python311\site-packages\keras\optimizers\legacy\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
early = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5,restore_best_weights=True)
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath="/kaggle/working/BEST.h5",
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             moniter='val_loss')

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', 
                              factor=0.2, 
                              patience=6, 
                              verbose=1, 
                              min_delta=0.0001)

# %%
FIT =model.fit(train_generator,
    validation_data = test_generator, 
    callbacks = [early , checkpoint,reduce_lr],
    epochs = 100)
# Out:
# C:\Users\mm\AppData\Roaming\Python\Python311\site-packages\keras\preprocessing\image.py:1861: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn(
# C:\Users\mm\AppData\Roaming\Python\Python311\site-packages\keras\preprocessing\image.py:1871: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn(
# Epoch 1/100
# 449/449 [==============================] - ETA: 0s - loss: 4.2517 - accuracy: 0.2575
# Epoch 1: val_loss improved from inf to 3.94626, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 725s 2s/step - loss: 4.2517 - accuracy: 0.2575 - val_loss: 3.9463 - val_accuracy: 0.2526 - lr: 1.0000e-04
# Epoch 2/100
# 449/449 [==============================] - ETA: 0s - loss: 3.4781 - accuracy: 0.3256
# Epoch 2: val_loss improved from 3.94626 to 3.28141, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 555s 1s/step - loss: 3.4781 - accuracy: 0.3256 - val_loss: 3.2814 - val_accuracy: 0.3321 - lr: 1.0000e-04
# Epoch 3/100
# 449/449 [==============================] - ETA: 0s - loss: 2.9406 - accuracy: 0.3749
# Epoch 3: val_loss improved from 3.28141 to 2.87674, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 570s 1s/step - loss: 2.9406 - accuracy: 0.3749 - val_loss: 2.8767 - val_accuracy: 0.3683 - lr: 1.0000e-04
# Epoch 4/100
# 449/449 [==============================] - ETA: 0s - loss: 2.5305 - accuracy: 0.4059
# Epoch 4: val_loss improved from 2.87674 to 2.35450, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 557s 1s/step - loss: 2.5305 - accuracy: 0.4059 - val_loss: 2.3545 - val_accuracy: 0.4248 - lr: 1.0000e-04
# Epoch 5/100
# 449/449 [==============================] - ETA: 0s - loss: 2.2226 - accuracy: 0.4258
# Epoch 5: val_loss improved from 2.35450 to 2.15891, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 561s 1s/step - loss: 2.2226 - accuracy: 0.4258 - val_loss: 2.1589 - val_accuracy: 0.4235 - lr: 1.0000e-04
# Epoch 6/100
# 449/449 [==============================] - ETA: 0s - loss: 1.9795 - accuracy: 0.4517
# Epoch 6: val_loss improved from 2.15891 to 1.82463, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 583s 1s/step - loss: 1.9795 - accuracy: 0.4517 - val_loss: 1.8246 - val_accuracy: 0.4772 - lr: 1.0000e-04
# Epoch 7/100
# 449/449 [==============================] - ETA: 0s - loss: 1.8013 - accuracy: 0.4669
# Epoch 7: val_loss improved from 1.82463 to 1.75369, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 551s 1s/step - loss: 1.8013 - accuracy: 0.4669 - val_loss: 1.7537 - val_accuracy: 0.4720 - lr: 1.0000e-04
# Epoch 8/100
# 449/449 [==============================] - ETA: 0s - loss: 1.6716 - accuracy: 0.4841
# Epoch 8: val_loss improved from 1.75369 to 1.58112, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 613s 1s/step - loss: 1.6716 - accuracy: 0.4841 - val_loss: 1.5811 - val_accuracy: 0.5054 - lr: 1.0000e-04
# Epoch 9/100
# 449/449 [==============================] - ETA: 0s - loss: 1.5694 - accuracy: 0.4992
# Epoch 9: val_loss improved from 1.58112 to 1.56269, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 553s 1s/step - loss: 1.5694 - accuracy: 0.4992 - val_loss: 1.5627 - val_accuracy: 0.4815 - lr: 1.0000e-04
# Epoch 10/100
# 449/449 [==============================] - ETA: 0s - loss: 1.4888 - accuracy: 0.5111
# Epoch 10: val_loss improved from 1.56269 to 1.49379, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 555s 1s/step - loss: 1.4888 - accuracy: 0.5111 - val_loss: 1.4938 - val_accuracy: 0.5079 - lr: 1.0000e-04
# Epoch 11/100
# 449/449 [==============================] - ETA: 0s - loss: 1.4331 - accuracy: 0.5189
# Epoch 11: val_loss improved from 1.49379 to 1.45397, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 542s 1s/step - loss: 1.4331 - accuracy: 0.5189 - val_loss: 1.4540 - val_accuracy: 0.5106 - lr: 1.0000e-04
# Epoch 12/100
# 449/449 [==============================] - ETA: 0s - loss: 1.3818 - accuracy: 0.5313
# Epoch 12: val_loss improved from 1.45397 to 1.41140, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 538s 1s/step - loss: 1.3818 - accuracy: 0.5313 - val_loss: 1.4114 - val_accuracy: 0.5063 - lr: 1.0000e-04
# Epoch 13/100
# 449/449 [==============================] - ETA: 0s - loss: 1.3395 - accuracy: 0.5429
# Epoch 13: val_loss improved from 1.41140 to 1.31626, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 576s 1s/step - loss: 1.3395 - accuracy: 0.5429 - val_loss: 1.3163 - val_accuracy: 0.5460 - lr: 1.0000e-04
# Epoch 14/100
# 449/449 [==============================] - ETA: 0s - loss: 1.3059 - accuracy: 0.5478
# Epoch 14: val_loss did not improve from 1.31626
# 449/449 [==============================] - 538s 1s/step - loss: 1.3059 - accuracy: 0.5478 - val_loss: 1.4303 - val_accuracy: 0.5074 - lr: 1.0000e-04
# Epoch 15/100
# 449/449 [==============================] - ETA: 0s - loss: 1.2851 - accuracy: 0.5538
# Epoch 15: val_loss did not improve from 1.31626
# 449/449 [==============================] - 590s 1s/step - loss: 1.2851 - accuracy: 0.5538 - val_loss: 1.3906 - val_accuracy: 0.5152 - lr: 1.0000e-04
# Epoch 16/100
# 449/449 [==============================] - ETA: 0s - loss: 1.2586 - accuracy: 0.5630
# Epoch 16: val_loss did not improve from 1.31626
# 449/449 [==============================] - 543s 1s/step - loss: 1.2586 - accuracy: 0.5630 - val_loss: 1.3665 - val_accuracy: 0.5177 - lr: 1.0000e-04
# Epoch 17/100
# 449/449 [==============================] - ETA: 0s - loss: 1.2387 - accuracy: 0.5659
# Epoch 17: val_loss improved from 1.31626 to 1.26949, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 559s 1s/step - loss: 1.2387 - accuracy: 0.5659 - val_loss: 1.2695 - val_accuracy: 0.5548 - lr: 1.0000e-04
# Epoch 18/100
# 449/449 [==============================] - ETA: 0s - loss: 1.2156 - accuracy: 0.5735
# Epoch 18: val_loss improved from 1.26949 to 1.26313, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 591s 1s/step - loss: 1.2156 - accuracy: 0.5735 - val_loss: 1.2631 - val_accuracy: 0.5567 - lr: 1.0000e-04
# Epoch 19/100
# 449/449 [==============================] - ETA: 0s - loss: 1.2035 - accuracy: 0.5793
# Epoch 19: val_loss improved from 1.26313 to 1.25564, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 556s 1s/step - loss: 1.2035 - accuracy: 0.5793 - val_loss: 1.2556 - val_accuracy: 0.5543 - lr: 1.0000e-04
# Epoch 20/100
# 449/449 [==============================] - ETA: 0s - loss: 1.1865 - accuracy: 0.5858
# Epoch 20: val_loss improved from 1.25564 to 1.24990, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 463s 1s/step - loss: 1.1865 - accuracy: 0.5858 - val_loss: 1.2499 - val_accuracy: 0.5646 - lr: 1.0000e-04
# Epoch 21/100
# 449/449 [==============================] - ETA: 0s - loss: 1.1660 - accuracy: 0.5932
# Epoch 21: val_loss did not improve from 1.24990
# 449/449 [==============================] - 461s 1s/step - loss: 1.1660 - accuracy: 0.5932 - val_loss: 1.4177 - val_accuracy: 0.4967 - lr: 1.0000e-04
# Epoch 22/100
# 449/449 [==============================] - ETA: 0s - loss: 1.1540 - accuracy: 0.5952
# Epoch 22: val_loss did not improve from 1.24990
# 449/449 [==============================] - 3510s 8s/step - loss: 1.1540 - accuracy: 0.5952 - val_loss: 1.3263 - val_accuracy: 0.5343 - lr: 1.0000e-04
# Epoch 23/100
# 449/449 [==============================] - ETA: 0s - loss: 1.1430 - accuracy: 0.6002
# Epoch 23: val_loss did not improve from 1.24990
# 449/449 [==============================] - 730s 2s/step - loss: 1.1430 - accuracy: 0.6002 - val_loss: 1.2600 - val_accuracy: 0.5584 - lr: 1.0000e-04
# Epoch 24/100
# 449/449 [==============================] - ETA: 0s - loss: 1.1322 - accuracy: 0.6043
# Epoch 24: val_loss did not improve from 1.24990
# 449/449 [==============================] - 585s 1s/step - loss: 1.1322 - accuracy: 0.6043 - val_loss: 1.2573 - val_accuracy: 0.5620 - lr: 1.0000e-04
# Epoch 25/100
# 449/449 [==============================] - ETA: 0s - loss: 1.1172 - accuracy: 0.6120
# Epoch 25: val_loss improved from 1.24990 to 1.20983, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 501s 1s/step - loss: 1.1172 - accuracy: 0.6120 - val_loss: 1.2098 - val_accuracy: 0.5846 - lr: 1.0000e-04
# Epoch 26/100
# 449/449 [==============================] - ETA: 0s - loss: 1.1056 - accuracy: 0.6138
# Epoch 26: val_loss improved from 1.20983 to 1.20423, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 471s 1s/step - loss: 1.1056 - accuracy: 0.6138 - val_loss: 1.2042 - val_accuracy: 0.5860 - lr: 1.0000e-04
# Epoch 27/100
# 449/449 [==============================] - ETA: 0s - loss: 1.0939 - accuracy: 0.6196
# Epoch 27: val_loss improved from 1.20423 to 1.18049, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 500s 1s/step - loss: 1.0939 - accuracy: 0.6196 - val_loss: 1.1805 - val_accuracy: 0.5887 - lr: 1.0000e-04
# Epoch 28/100
# 449/449 [==============================] - ETA: 0s - loss: 1.0877 - accuracy: 0.6202
# Epoch 28: val_loss did not improve from 1.18049
# 449/449 [==============================] - 532s 1s/step - loss: 1.0877 - accuracy: 0.6202 - val_loss: 1.2171 - val_accuracy: 0.5829 - lr: 1.0000e-04
# Epoch 29/100
# 449/449 [==============================] - ETA: 0s - loss: 1.0700 - accuracy: 0.6277
# Epoch 29: val_loss improved from 1.18049 to 1.18045, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 462s 1s/step - loss: 1.0700 - accuracy: 0.6277 - val_loss: 1.1805 - val_accuracy: 0.5823 - lr: 1.0000e-04
# Epoch 30/100
# 449/449 [==============================] - ETA: 0s - loss: 1.0620 - accuracy: 0.6310
# Epoch 30: val_loss improved from 1.18045 to 1.15543, saving model to /kaggle/working\BEST.h5
# 449/449 [==============================] - 479s 1s/step - loss: 1.0620 - accuracy: 0.6310 - val_loss: 1.1554 - val_accuracy: 0.5982 - lr: 1.0000e-04
# Epoch 31/100
# 449/449 [==============================] - ETA: 0s - loss: 1.0512 - accuracy: 0.6361
# Epoch 31: val_loss did not improve from 1.15543
# 449/449 [==============================] - 508s 1s/step - loss: 1.0512 - accuracy: 0.6361 - val_loss: 1.2054 - val_accuracy: 0.5777 - lr: 1.0000e-04
# Epoch 32/100
# 449/449 [==============================] - ETA: 0s - loss: 1.0487 - accuracy: 0.6334
# Epoch 32: val_loss did not improve from 1.15543
# 449/449 [==============================] - 483s 1s/step - loss: 1.0487 - accuracy: 0.6334 - val_loss: 1.1743 - val_accuracy: 0.5947 - lr: 1.0000e-04
# Epoch 33/100
# 449/449 [==============================] - ETA: 0s - loss: 1.0316 - accuracy: 0.6411
# Epoch 33: val_loss did not improve from 1.15543
# 449/449 [==============================] - 494s 1s/step - loss: 1.0316 - accuracy: 0.6411 - val_loss: 1.1923 - val_accuracy: 0.5995 - lr: 1.0000e-04
# Epoch 34/100
# 449/449 [==============================] - ETA: 0s - loss: 1.0230 - accuracy: 0.6427
# Epoch 34: val_loss did not improve from 1.15543
# 449/449 [==============================] - 477s 1s/step - loss: 1.0230 - accuracy: 0.6427 - val_loss: 1.1570 - val_accuracy: 0.5963 - lr: 1.0000e-04
# Epoch 35/100
# 449/449 [==============================] - ETA: 0s - loss: 1.0170 - accuracy: 0.6519
# Epoch 35: val_loss did not improve from 1.15543
# 449/449 [==============================] - 488s 1s/step - loss: 1.0170 - accuracy: 0.6519 - val_loss: 1.1774 - val_accuracy: 0.6000 - lr: 1.0000e-04

# %%
plt.figure(figsize=(14,5))
plt.subplot(1,2,2)
plt.plot(FIT.history['accuracy'])
plt.plot(FIT.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['train', 'test'], loc='upper left')

plt.subplot(1,2,1)
plt.plot(FIT.history['loss'])
plt.plot(FIT.history['val_loss'])
plt.title('model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
